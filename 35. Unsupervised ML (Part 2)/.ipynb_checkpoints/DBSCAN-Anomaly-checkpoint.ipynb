# %% [markdown]
# # Machine Learning:
# - __DBSCAN Clustering Algorithm for Anomaly Detection.__
# - Density-Based Spatial Clustering of Applications with Noise Algorithm.
# - Unsupervised Machine Learning.
