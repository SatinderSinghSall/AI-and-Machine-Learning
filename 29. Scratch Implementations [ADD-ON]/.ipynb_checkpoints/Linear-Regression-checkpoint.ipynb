# %% [markdown]
# ## Machine Learning: Supervised Learning:
# - Linear Regression Algorithm
# - __Scratch Implementation__ of Linear Regression Algorithm.

# %%
import numpy as np

# %% [markdown]
# ## Linear Regression:

# %%
class LinearRegression:
    def __init__(self, learning_rate = 0.01, n_iter):
        self.bias = None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

    def fit(self, X, y): # X_train, y_train
        m, n =X.shape # number of samples (row) & fearures (cols)

        # Step - 1: Random Initialisation.
        self.bias = 0
        self.weights = np.zeros(n) # [0, 0, ..., 0]

        # Step - 2: Calculate Prediction Values.
        y_pred = self.bias + np.dot(X, self.weights)

        # Step - 3: Calculate Derivatives / Gradients.
        

    def predict(self. ):
