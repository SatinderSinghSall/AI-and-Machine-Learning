# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Histograms:

# %%
np.random.seed(0)
scores = np.random.normal(70, 10, 1000)
plt.hist(scores)
# Out:
# (array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.]),
#  array([39.53856945, 45.34406762, 51.14956579, 56.95506396, 62.76056213,
#         68.5660603 , 74.37155846, 80.17705663, 85.9825548 , 91.78805297,
#         97.59355114]),
#  <BarContainer object of 10 artists>)
