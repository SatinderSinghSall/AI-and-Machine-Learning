# %% [markdown]
# # First Tutorial:
# ## This is a tutorial on how to use Jupyter Notebook
# - Bullet Point 1

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 20
b = 30
sum = a + b
print(f"Sum: {a} + {b} = {sum}")
# Out:
# Sum: 20 + 30 = 50
